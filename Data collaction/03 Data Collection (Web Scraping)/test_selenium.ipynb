# %%
import requests
import json
from bs4 import BeautifulSoup

# %%
#This will not run on online IDE
import requests
from bs4 import BeautifulSoup

URL = "https://bookshop.org/gift_cards"
r = requests.get(URL)

soup = BeautifulSoup(r.text, 'html.parser')
# print(soup.prettify())

# %%
r
# Out:
# <Response [403]>

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
data = soup.find_all('ul')

# %%
data
# Out:
# []

# %%
from selenium import webdriver
from bs4 import BeautifulSoup
import time

driver = webdriver.Chrome()
driver.get("https://bookshop.org/gift_cards")

time.sleep(5)  # wait for JS to load

soup = BeautifulSoup(driver.page_source, 'html.parser')
uls = soup.find_all('ul')
print(uls)

driver.quit()
# Out:
# [<ul class="menu-list">
# <li><a href="https://bookshop.org/pages/bookstores">Choose a Bookstore</a></li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a href="https://bookshop.org/ebooks" id="Ebooks-sub-menu">
#                     Ebooks
#                   </a>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a href="https://bookshop.org/gift_cards" id="Gift+Cards-sub-menu">
#                     Gift Cards
#                   </a>
# </li>
# <li class="navbar-item has-dropdown is-hoverable">
# <a data-action="click-&gt;Nav--mobile-categories#openSubItem" data-subnav-target-id="Special+Offers" href="https://bookshop.org/lists/special-offers-on-bookshop-org" id="Special+Offers-sub-menu">
#                     Special Offers
#                     <img alt="" src="
# https://rails-assets-us.bookshop.org/ds/images/chevron-right.7be3f13058fcb4713eaf7866bad97d0f6a752ed3.svg
# " title="Special Offers"/>
# </a>
# </li>
# ...

# %%
test = soup.find_all('li')
test
# Out:
# [<li><a href="https://bookshop.org/pages/bookstores">Choose a Bookstore</a></li>,
#  <li class="navbar-item has-dropdown is-hoverable">
#  <a href="https://bookshop.org/ebooks" id="Ebooks-sub-menu">
#                      Ebooks
#                    </a>
#  </li>,
#  <li class="navbar-item has-dropdown is-hoverable">
#  <a href="https://bookshop.org/gift_cards" id="Gift+Cards-sub-menu">
#                      Gift Cards
#                    </a>
#  </li>,
#  <li class="navbar-item has-dropdown is-hoverable">
#  <a data-action="click-&gt;Nav--mobile-categories#openSubItem" data-subnav-target-id="Special+Offers" href="https://bookshop.org/lists/special-offers-on-bookshop-org" id="Special+Offers-sub-menu">
#                      Special Offers
#                      <img alt="" src="
#  https://rails-assets-us.bookshop.org/ds/images/chevron-right.7be3f13058fcb4713eaf7866bad97d0f6a752ed3.svg
#  " title="Special Offers"/>
#  </a>
#  </li>,
# ...

# %%
data_text = []

for i in test:
    data_text.append(i.text)
data_text
# Out:
# ['Choose a Bookstore',
#  '\n\n                    Ebooks\n                  \n',
#  '\n\n                    Gift Cards\n                  \n',
#  '\n\n                    Special Offers\n                    \n\n',
#  '\n\n                    Refer A Friend\n                  \n',
#  '\n\n                    New Books\n                  \n',
#  '\n\n                    Best Sellers\n                  \n',
#  '\n\n                    Fiction\n                    \n\n',
#  '\n\n                    Nonfiction\n                    \n\n',
#  '\n\n                    YA\n                  \n',
#  '\n\n                    Kids\n                  \n',
#  '\n\n                    Games & Puzzles\n                  \n',
#  '\n\n\n                    Special Offers\n                  \n',
#  'See all Special Offers',
#  'FSG & Picador Present: 15% off Select Titles',
#  'Get 15% off great reads from DK!',
#  'Stellar Reads from Bloomsbury! Get 15% Off',
# ...

# %%
target_text = data_text[-8:-7]
target_text = str(target_text)
target_text
# Out:
# "['\\n    If you purchase a gift card from a specific store or affiliate on Bookshop.org, the recipient will be sent to the\\n    same store on our site when they click the link to redeem the card, so the store will get credit for any purchases\\n    made. However, it is possible for a customer to change to a different shop affiliation if they want to spread their\\n    purchases around--the card is like cash, and can be spent how the recipient wants.\\n  ']"

# %%
target_text = target_text.replace('\\n', '').strip().removeprefix('[').removesuffix(']').strip().replace("'", "").replace(",", "").strip()
target_text
# Out:
# 'If you purchase a gift card from a specific store or affiliate on Bookshop.org the recipient will be sent to the    same store on our site when they click the link to redeem the card so the store will get credit for any purchases    made. However it is possible for a customer to change to a different shop affiliation if they want to spread their    purchases around--the card is like cash and can be spent how the recipient wants.'
